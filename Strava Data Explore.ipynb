# %% [markdown]
# # Strava Visualisor

# %% [markdown]
# ### Get Data from Strava

# %%
import json
import pandas as pd
from stravalib.client import Client
from pprint import pprint
import matplotlib.pyplot as plt
# Installation guide
# https://stackoverflow.com/questions/50597854/problems-with-future-and-swagger-client-in-python

# %%
login_details = {'Client ID': 34948, 'Client Secret': '0737f43d025352ed5cb83519e9095a271b04c0ef'
                 , 'Code': 'bc1de4a08a69a21980171c6f0f079b8876aad740', 'Athlete ID': 20401536}
# with open('logins.json', 'r') as f:
#     login_details = json.load(f)

# %%
# import request
code = 'bc1de4a08a69a21980171c6f0f079b8876aad740'
client = Client()
code = client.exchange_code_for_token(login_details['Client ID'],
                                     login_details['Client Secret'],
                                     code)
print(url)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-de05670172a0> in <module>()
#       4 code = client.exchange_code_for_token(login_details['Client ID'],
#       5                                      login_details['Client Secret'],
# ----> 6                                      code)
#       7 print(url)
#
# C:\ProgramData\Anaconda3\lib\site-packages\stravalib\client.py in exchange_code_for_token(self, client_id, client_secret, code)
#     131         return self.protocol.exchange_code_for_token(client_id=client_id,
#     132                                                      client_secret=client_secret,
# --> 133                                                      code=code)
#     134
#     135     def refresh_access_token(self, client_id, client_secret, refresh_token):
#
# C:\ProgramData\Anaconda3\lib\site-packages\stravalib\protocol.py in exchange_code_for_token(self, client_id, client_secret, code)
#     129         access_info = dict()
#     130         access_info['access_token'] = response['access_token']
# --> 131         access_info['refresh_token'] = response['refresh_token']
#     132         access_info['expires_at'] = response['expires_at']
#     133         self.access_token = response['access_token']
#
# KeyError: 'refresh_token'

# %%
# login not stored on git
# login_details = {'Client ID': , 'Client Secret': '',
#           'Access Token': ''}
# with open('logins.json', 'r') as f:
#     login_details = json.load(f)

client = Client(access_token='e405704ed45de2d99d83c8e981a067e980f0aa8b')

# %%
activities = client.get_activities()
sample = list(activities)[0]
pprint(sample.to_dict())


# Get all my activities get the date and the GPS coords
# Might need to make sure there are GPS coords
activity_coords = []
for activity in activities:
    poly_coord = {'Poly': activity.to_dict()['map']['summary_polyline'],
                  'Date': activity.to_dict()['start_date'].split('T')[0]}
    if poly_coord['Poly'] is not None:
        activity_coords.append(poly_coord)
# for activity in activities:
#     print(activity.to_dict()['upload_id'])
activity_coords
# Out:
# {'achievement_count': 2,
#  'athlete': {'admin': None,
#              'agreed_to_terms': None,
#              'approve_followers': None,
#              'athlete_type': None,
#              'badge_type_id': None,
#              'bikes': None,
#              'city': None,
#              'clubs': None,
#              'country': None,
#              'created_at': None,
#              'date_preference': None,
#              'dateofbirth': None,
#              'description': None,
#              'email': None,
#              'email_facebook_twitter_friend_joins': None,
#              'email_kom_lost': None,
#              'email_language': None,
#              'email_send_follower_notices': None,
#              'facebook_sharing_enabled': None,
#              'firstname': None,
#              'follower': None,
#              'follower_count': None,
#              'follower_request_count': None,
#              'friend': None,
#              'friend_count': None,
#              'ftp': None,
#              'global_privacy': None,
#              'instagram_username': None,
#              'lastname': None,
#              'max_heartrate': None,
#              'measurement_preference': None,
#              'membership': None,
#              'mutual_friend_count': None,
#              'offer_in_app_payment': None,
#              'owner': None,
#              'plan': None,
#              'premium': None,
#              'premium_expiration_date': None,
#              'profile': None,
#              'profile_medium': None,
#              'profile_original': None,
#              'receive_comment_emails': None,
#              'receive_follower_feed_emails': None,
#              'receive_kudos_emails': None,
#              'receive_newsletter': None,
#              'sample_race_distance': None,
#              'sample_race_time': None,
#              'sex': None,
#              'shoes': None,
#              'state': None,
#              'subscription_permissions': None,
#              'super_user': None,
#              'updated_at': None,
#              'username': None,
#              'weight': None},
#  'athlete_count': 2,
#  'average_cadence': 86.4,
#  'average_heartrate': 168.9,
#  'average_speed': 3.197,
#  'average_temp': None,
#  'average_watts': None,
#  'best_efforts': None,
#  'calories': None,
#  'comment_count': 0,
#  'commute': False,
#  'description': None,
#  'device_name': None,
#  'device_watts': None,
#  'distance': 4022.1,
#  'elapsed_time': '0:21:20',
#  'elev_high': 11.6,
#  'elev_low': -0.7,
#  'embed_token': None,
#  'end_latlng': '52.66,-8.63',
#  'external_id': 'garmin_push_3612000896',
#  'flagged': False,
#  'from_accepted_tag': False,
#  'gear': None,
#  'gear_id': None,
#  'guid': None,
#  'has_heartrate': True,
#  'has_kudoed': False,
#  'highlighted_kudosers': None,
#  'instagram_primary_photo': None,
#  'kilojoules': None,
#  'kudos_count': 0,
#  'laps': None,
#  'location_city': None,
#  'location_country': None,
#  'location_state': None,
#  'manual': False,
#  'map': {'id': 'a2336802944',
#          'polyline': None,
#          'summary_polyline': 'kil`I||ts@cNn]|AyCbT`wB{CTqEgIyNab@`BsClFqA|BmIoJ}^UcLrAqJ|KeW'},
#  'max_heartrate': 191,
#  'max_speed': 4.0,
#  'max_watts': None,
#  'moving_time': '0:20:58',
#  'name': 'Evening Run',
#  'partner_brand_tag': None,
#  'partner_logo_url': None,
#  'photo_count': 0,
#  'photos': None,
#  'pr_count': 1,
#  'private': False,
#  'segment_efforts': None,
#  'segment_leaderboard_opt_out': None,
#  'splits_metric': None,
#  'splits_standard': None,
#  'start_date': '2019-05-02T17:40:20+00:00',
#  'start_date_local': '2019-05-02T18:40:20',
#  'start_latitude': 52.66,
#  'start_latlng': '52.66,-8.63',
#  'start_longitude': -8.63,
#  'suffer_score': None,
#  'timezone': 'Europe/Dublin',
#  'total_elevation_gain': 24.6,
#  'total_photo_count': 0,
#  'trainer': False,
#  'type': 'Run',
#  'upload_id': '2486311497',
#  'utc_offset': 3600.0,
#  'weighted_average_watts': None,
#  'workout_type': None}
# [{'Date': '2019-05-02',
#   'Poly': 'kil`I||ts@cNn]|AyCbT`wB{CTqEgIyNab@`BsClFqA|BmIoJ}^UcLrAqJ|KeW'},
#  {'Date': '2019-05-01',
#   'Poly': 'igl`Ifyts@mPja@xAuCpGlw@{Jga@GeJzAaKq@mHwOwSdGsJfR~UxAcB'},
#  {'Date': '2019-04-30',
#   'Poly': 'kfl`Ituts@oQxd@hB}CtSjwB_CBeF}H_Oic@xIqD|B_I_A}IiHmTa@kLfAyHrIiT'},
#  {'Date': '2019-04-29', 'Poly': 'ixl`Irqus@}AeH}MaQtGaJ|RxV'},
#  {'Date': '2019-04-18',
#   'Poly': 'cfl`Ibaus@aM~XiBp@~AeDfShwBwCEgIgOgKg\\jBaDtEq@dCkKaBcLsHiTLsLzAqHwA_KuNaQ~HwPnApAu@nExPnT'},
#  {'Date': '2019-03-28',
#   'Poly': 'mql`If~ts@zBhHoJvRnBwCpTfvB{Ch@q@lH}BrEmIjDeIyKiHul@tNmKxEm@pCkJiKob@wC_E~DoY}OeT~HePdBrAmAjC|AzB'},
#  {'Date': '2019-03-25',
#   'Poly': 'efl`Ilsts@aQxf@vAyCrSdwBcD]gEqHkOoa@fIuExC{I_Kw_@MaMbBcJwAuK{N{P`G_KbSdWlBuE'},
#  {'Date': '2019-01-11',
#   'Poly': 'ifl`Iftts@wCfLqBNyNoRdKbKnCxHwRiXkG|IcJqRyJr@tF{AfD~A|IbS`MnNnCvMvKeZ'},
#  {'Date': '2018-08-22',
#   'Poly': '_il`Ij|ts@sNv]|@{Cf@h@xShpBGtDqB\\kI{NcLm]bIgDnCqMgKy_@AuIbBwKg@iGgPkTxFaK|SbWrAyEoByCdBsG'},
#  {'Date': '2018-08-14',
#   'Poly': '{hl`I~|ts@_Ol]dBsCvGtw@qKma@A{K~AsJ}@_GyOwSpFgK|RtW`FaM'},
#  {'Date': '2018-07-31',
#   'Poly': 'mel`I`tts@gRff@rAoDjSlxBqBHgH}MgLi^lIiDhCmJwJ_`@SkLtAaItMw['},
#  {'Date': '2018-06-27',
#   'Poly': 'uaf`Ih_zs@tIkRgHuUwU_YoByL@uI`GrCnV_BbC`H~IbDdBrDxCt_@gL~IcNhZ'},
#  {'Date': '2018-06-20',
#   'Poly': '}el`Ivwts@kQvc@dBgCpSvnBDbE_B\\s@oBt@aAgArCuEaIgNaa@dIoEfCeJu@_JiIkWK{IvAaItNe^'},
#  {'Date': '2018-06-10',
#   'Poly': 'oql`Ilpus@wDzHg@vMTxBvDKlEr`@eDtL}Dz@}DoPnElPdD_BvB_KmJm]UgNxOad@'},
#  {'Date': '2018-04-23',
#   'Poly': 'q|d`Id}ws@eBeCwFlCrBvYqClCxA|HqM`HmKvZfFjJdC|Dp@sAfXkm@}B_KyEnCgByFvUsPn@kAkBgF'},
#  {'Date': '2018-04-17',
#   'Poly': '_|d`If}ws@aBcCwFhChBpYwMlMcNd[gCfNtDbGPjDoFjP}GbIs@rFuObE}DjHYnd@nT|DsAbOlBbH}@bJqGwCuG{a@rQfCyAbL^`GnAzAw@zHa@dAaGwD}@wMsEwRrQrBuAjOlBjHwAzIkGsEm@uLwEwNC}D}AyAR{`@tEwKjLmEzRm^\\aHvAaBwBsF\\aD|JaVhLgJy@{HhCcCaAiHZmN'},
#  {'Date': '2018-04-13',
#   'Poly': '{{d`I|}ws@aBwCeGnCRxMbBdJuC~DpAxGiLlHwKn^bIrKz@YpLc\\fJ{PeBsKgSrMoL``@tIfLjA}BbW_l@uA}IcFxB_BiHfRgMnAsD'},
#  {'Date': '2018-04-09',
#   'Poly': 'meg`Iny}s@jQ|BkA|ObBrHeA|IaH}EoAsQyD_LnQRaAhPjBrGkAtJ{GcEm@}L_FyRzQhBoA`NfBzGoApKwGiEwAqQwD{LvQj@gAbPfBbHaB`JwGuEc@{L{EgPvQd@mAtLlBbJcAdK}GoEuAsQyD}MtJX'},
#  {'Date': '2018-04-03',
#   'Poly': 'm|d`Ip~ws@_BcDuFzBhBnZkCpCpAjHsMvIsJl\\`K`KxIgWnG}K_@yCsEqGqKxHoJfZpItMz@g@dJ_WhMeVmByJwFxBgAoFdViQuBiIuBqA'},
#  {'Date': '2018-03-26',
#   'Poly': 'c~d`Iz|ws@q@mBqFfCpB~XgChDnAhHsMhJqJx\\xJnKvKuZ|KoScCwJaShNwLx]~JlLpXen@qAmJoFxBoBgG~TyQQqEeDaE'},
#  {'Date': '2018-03-13',
#   'Poly': 'm|d`I~~ws@yA_D}FhCfBjX_CvD~@jHcN|JwIj[lJlL~HuS|XfYbInDbE]zFcHlBqIGiJuEyQsLpKwFyFaGgMkDrGwGsIp@{Ag@gJzUqPeDeKgBi@'},
#  {'Date': '2018-03-11',
#   'Poly': 'c|d`It}ws@uAiCgGhCnBnYiClChAhHyMjJoJr[bJpMdH_RfBi@rVbYtIxCzGuBnDsF`BkLkEyX}MtKsFwEkIcRm@eFuFbCsAiEbCmElQuLyBqJ_B}@'},
#  {'Date': '2018-03-08',
#   'Poly': 'g|d`I|}ws@cBqCwF`B}BaHiKiEsBuGkVbB}FwC|AtVnTdYoPfn@lOjP|FHbElFtJaTtXzYbI`DbIeEpCyF~@mKyEcWiMbKmNaUuJfPcN~]{AKgHeLvJoZjMoJs@mJtVyQ_DqIgBm@'},
#  {'Date': '2018-03-06',
#   'Poly': 'o{d`I|}ws@oBqCaGxClBjXyQdTkHzQsD~QjE|CfC}@~DhFnKoYvL_U{AkKsSlMkMv]~JdNvRee@DmBmEgHh@yCkAeGxVyQyCkJyBcA'},
#  {'Date': '2018-03-05',
#   'Poly': 'k|d`Ib}ws@}AaCuFnChBbZaClC~@pHaMpH{Jb^pJ|K|Xso@sBwJiVvRyIpY~IrMfKyXnMeVcBoJwF|ByAgGhVyPuCoKwBq@'},
#  {'Date': '2018-02-27',
#   'Poly': 'w{d`In}ws@cBeC}F`CdBjZ_CjCdAvGiMlI{Jj^nJhK`Sif@{F}JyKrHgJbZzIdNvY}o@aB{JwEpCsBaGrV_R{CqJaCcA'},
#  {'Date': '2018-02-25',
#   'Poly': 'm|d`Il~ws@sAiDcG`ByB{GiJmD}CyH_NdBwO{B~BfVbTbZuPdm@zNrObIjAtCpDxGcR~A_AhVvXdHbDhFRfGyG~ByHVsHeF}TkMfKcO_UgB{IsGvAs@_EpGwHyD_AoAgS|FyB'},
#  {'Date': '2018-02-23',
#   'Poly': '{{d`It}ws@aBmC}FnCdBrYeCrC~@rHyM|IsJv[pJdM|IiSjFhHtE`B`IhMdIxDrFeAbHmK~@gOmE{SuMhKkF{FqFyLyJdOyNf_@qJaMjKq[fLeI_@oJhVsQiDqJeBe@'},
#  {'Date': '2018-02-21',
#   'Poly': 'a|d`Ij}ws@_BiCyFpCjBdYkCzCv@hIgLxGoKf]`JnM|GcRdBq@`WpYjI~CjEi@nF_HxBmMY}HoDaN{MrJiFgFeGuM_ElGmGsJz@aAo@aJ|SwN@mFcEiF'},
#  {'Date': '2018-02-18',
#   'Poly': 'u{d`I`}ws@s@b@w@}C{FfBmDeIgIsC}BoHkVzA}N_FyLzFy]|`@jLrRp`@jTtNpTrKnKlCjA~AcBzEjGbTkg@cF}Ij@uCaAqGjSoNxAwDqI{N_BbA\\~B'},
#  {'Date': '2018-02-16',
#   'Poly': 'q{d`Ij}ws@m@d@gAaDcGhCpBvYiQzRkGhOgFxTxJ`CnDxDhY_p@uB{J}EtCaBgGzByBaBcZhHg@'},
#  {'Date': '2018-02-14',
#   'Poly': 'c}d`Il~ws@y@gDgGtCpB|XgCzC`AxHgMnIeKx[|IxMxJ}T~VxY~J|DvDq@pGqI|AaI]sJgE}OiMtKmFiFuF{MoEpGyFmIt@sB_AoHrBkDjRoLqCwJmCcA'},
#  {'Date': '2018-02-13',
#   'Poly': 'w{d`Ij}ws@k@`@g@{DsGbC\\pO|AfIkCjCbAnHgMvIwJ`\\dJtMdIsSfXpYpIbDzFgAlEkGnBiIAiHqFaSoLvKcOkUcEjG{FkHBmM|UeQqCoJeCu@'},
#  {'Date': '2018-02-08',
#   'Poly': 'u{d`Ib~ws@kB{BcGpCnAdY}B~BpAjHaMpIuJ~[~IpMrIoSfLnIlKdN`JnDrEeA~FoIpAuI]uHuDgO_Ak@wKxKgFyE}HgOeBgI_TlN_Lp]zJrLnXgo@gAqIyFpBmBgGjTqOViFmByEuBq@'},
#  {'Date': '2018-02-06',
#   'Poly': 'a|d`I`}ws@}@Nq@yC}F~AcAoFkKqEsDwH{TlA}GcCpAhUnItObI`IcPrn@xI|JxA_AdOo`@fEgH`KiH}@wI\\aKjDeG'},
#  {'Date': '2018-02-01',
#   'Poly': '}|d`I|~ws@_AqDeGpChBnXaCpD~@nH{LnHyKb]bK|LbSah@wFcI_LdIiJnYbKjMjS{f@oFsJdGgE|CvHgDpFeG_J~@wAeAmH`CqCaBaYtF_C'},
#  {'Date': '2018-01-30',
#   'Poly': 'e{d`I`~ws@{@RaAaDeGhAoBcG_KuEqCqG{O`BsMeCrBlVbTrYkPbn@vO~OrFKvE~ElSgf@gFsJd@gCaAuG`WsRoDkJmEqE}@xC'},
#  {'Date': '2018-01-22',
#   'Poly': 'u|d`Ip}ws@uAoCiGfDtBhYsChBtAtIsMbJ{Jd[jJpM|Saf@wFyKcIjE_DfF_HvWrJfL~Rse@{EkKj@oCeAmGdU}QcBuJoB_@eByDsAvA\\fB'},
#  {'Date': '2018-01-15',
#   'Poly': 'k|d`If_xs@uBaEsFhCbBnY_CzCz@|GcMpJeJfX?`DpJrJnXyo@aB}IoUbR`KdNdGyLiFeJp@sBcA{GpTcQAkFoE}E'},
#  {'Date': '2017-12-03',
#   'Poly': '}{d`I`~ws@uAgDgGxC|A|XoBlDh@zG}KdI}Kv\\rIzMxIiTbZjZvHnCtGeBbEcHjA{IYwIkE{O_MxKqOgU_B_J{G|Ay@{DdCiEmBiXlEeB'},
#  {'Date': '2017-11-20',
#   'Poly': 'u}d`Ih}ws@s@}B{FfCrB`ZiCdCbAlImLtGmL~]tJzLpJuUvWh[vJ~ChGyC|D{GlAeKoFkXgM~KgOoU{AoIcFlC}B_EfCaGhP_JYcJsDuC'},
#  {'Date': '2017-11-09',
#   'Poly': 'y{d`Ih}ws@kBoC}FnC|BrZmCzB~@hIaMpHuKl\\|JtMtS_g@kGwKsG`EsCtDyIdZtJnMdS{f@sFiKhAqBoAoHpSkObAiDuB{GwD_A'},
#  {'Date': '2017-06-18',
#   'Poly': 'c{d`I~}ws@l@eCeAuBuJ`FdDzYcDxCdAzGnGwDExCxJtSxFvFfMaLpF`XUbI}K~RdEj[o[vTfBlKrGhRxZvh@nKlXrLvOzNbYlw@lo@nHwKdDmA|NfB~HkBfLyN`HyPnFcG`CsMbHsIpDeM|HuNvGy^xVaq@HwG`YyR_Fyj@eOkl@]eZaCyRaLi`@{M_o@{EhCmeAxCkPxD{TkViR_ImX~@k`@~RyVrEq\\aAyb@}GkHrMiBrO?la@rN\\nGkDeApBhBtGjKlEbBpHnGoB|@rDn@e@'}]

# %%
# from __future__ import print_statement
import time
import swagger_client
from swagger_client.rest import ApiException
from pprint import pprint

# Configure OAuth2 access token for authorization: strava_oauth
swagger_client.configuration.access_token = 'YOUR_ACCESS_TOKEN'

# create an instance of the API class
api_instance = swagger_client.ActivitiesApi()
before = 56 # Integer | An epoch timestamp to use for filtering activities that have taken place before a certain time. (optional)
after = 56 # Integer | An epoch timestamp to use for filtering activities that have taken place after a certain time. (optional)
page = 56 # Integer | Page number. (optional)
perPage = 56 # Integer | Number of items per page. Defaults to 30. (optional) (default to 30)

try: 
    # List Athlete Activities
    api_response = api_instance.getLoggedInAthleteActivities(before=time.time(), after=after)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling ActivitiesApi->getLoggedInAthleteActivities: %s\n" % e)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-3bb7782c784f> in <module>()
#      17 try:
#      18     # List Athlete Activities
# ---> 19     api_response = api_instance.getLoggedInAthleteActivities(before=time.time(), after=after)
#      20     pprint(api_response)
#      21 except ApiException as e:
#
# AttributeError: 'ActivitiesApi' object has no attribute 'getLoggedInAthleteActivities'

# %%
import polyline

coord = polyline.decode('kil`I||ts@cNn]|AyCbT`wB{CTqEgIyNab@`BsClFqA|BmIoJ}^UcLrAqJ|KeW')

fig = plt.figure(figsize=(12,12))
fig.suptitle('Strava Activity in Des Moines, Iowa')
ax = plt.Axes(fig, [0., 0., 1., 1.], )
ax.set_aspect('equal')
ax.set_axis_off()
fig.add_axes(ax)

# for coo in coo_list:
lat,lon = map(list, zip(*coord))
plt.plot(lon, lat, lw=0.5, alpha=.9)

# %%
# coo_list = [polyline.decode(x['map']['summary_polyline']) for x in records
#             if x['timezone'] == '(GMT-06:00) America/Chicago'
#             and x['start_latlng'] is not None
#             and x['start_latlng'][0] <= 41.6 and round(x['start_latlng'][0],1) >= 41.2 and round(x['start_latlng'][1]) == -94]

# %%
fig = plt.figure(figsize=(12,12))
fig.suptitle('My Strava Summary')
ax = plt.Axes(fig, [0., 0., 1., 1.], )
ax.set_aspect('equal')
ax.set_axis_off()
fig.add_axes(ax)

for act in activity_coords:
    coord = polyline.decode(act['Poly'])
    lat,lon = map(list, zip(*coord))
    plt.plot(lon, lat, lw=0.5, alpha=.9, label=act['Date'])
    
plt.legend(loc=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__warningregistry__',
#  '_auto_draw_if_interactive',
#  '_autogen_docstring',
#  '_backend_mod',
#  '_backend_selection',
#  '_hold_msg',
#  '_imread',
#  '_imsave',
#  '_interactive_bk',
#  '_pylab_helpers',
#  '_setp',
#  '_setup_pyplot_info_docstrings',
#  '_show',
#  '_string_to_bool',
#  'absolute_import',
#  'acorr',
#  'angle_spectrum',
#  'annotate',
#  'arrow',
#  'autoscale',
#  'autumn',
#  'axes',
#  'axhline',
#  'axhspan',
#  'axis',
#  'axvline',
#  'axvspan',
#  'bar',
#  'barbs',
#  'barh',
#  'bone',
#  'box',
#  'boxplot',
#  'broken_barh',
#  'cla',
#  'clabel',
#  'clf',
#  'clim',
#  'close',
#  'cm',
#  'cohere',
#  'colorbar',
#  'colormaps',
#  'colors',
#  'connect',
#  'contour',
#  'contourf',
#  'cool',
#  'copper',
#  'csd',
#  'cycler',
#  'dedent',
#  'delaxes',
#  'deprecated',
#  'disconnect',
#  'division',
#  'docstring',
#  'draw',
#  'draw_all',
#  'draw_if_interactive',
#  'errorbar',
#  'eventplot',
#  'figaspect',
#  'figimage',
#  'figlegend',
#  'fignum_exists',
#  'figtext',
#  'figure',
#  'fill',
#  'fill_between',
#  'fill_betweenx',
#  'findobj',
#  'flag',
#  'gca',
#  'gcf',
#  'gci',
#  'get',
#  'get_backend',
#  'get_cmap',
#  'get_current_fig_manager',
#  'get_figlabels',
#  'get_fignums',
#  'get_plot_commands',
#  'get_scale_docs',
#  'get_scale_names',
#  'getp',
#  'ginput',
#  'gray',
#  'grid',
#  'hexbin',
#  'hist',
#  'hist2d',
#  'hlines',
#  'hold',
#  'hot',
#  'hsv',
#  'imread',
#  'imsave',
#  'imshow',
#  'inferno',
#  'install_repl_displayhook',
#  'interactive',
#  'ioff',
#  'ion',
#  'is_numlike',
#  'ishold',
#  'isinteractive',
#  'jet',
#  'legend',
#  'locator_params',
#  'loglog',
#  'magma',
#  'magnitude_spectrum',
#  'margins',
#  'matplotlib',
#  'matshow',
#  'minorticks_off',
#  'minorticks_on',
#  'mlab',
#  'new_figure_manager',
#  'nipy_spectral',
#  'np',
#  'over',
#  'pause',
#  'pcolor',
#  'pcolormesh',
#  'phase_spectrum',
#  'pie',
#  'pink',
#  'plasma',
#  'plot',
#  'plot_date',
#  'plotfile',
#  'plotting',
#  'polar',
#  'print_function',
#  'prism',
#  'psd',
#  'pylab_setup',
#  'quiver',
#  'quiverkey',
#  'rc',
#  'rcParams',
#  'rcParamsDefault',
#  'rc_context',
#  'rcdefaults',
#  'register_cmap',
#  'rgrids',
#  'savefig',
#  'sca',
#  'scatter',
#  'sci',
#  'semilogx',
#  'semilogy',
#  'set_cmap',
#  'setp',
#  'show',
#  'silent_list',
#  'six',
#  'specgram',
#  'spectral',
#  'spring',
#  'spy',
#  'stackplot',
#  'stem',
#  'step',
#  'streamplot',
#  'style',
#  'subplot',
#  'subplot2grid',
#  'subplot_tool',
#  'subplots',
#  'subplots_adjust',
#  'summer',
#  'suptitle',
#  'switch_backend',
#  'sys',
#  'table',
#  'text',
#  'thetagrids',
#  'tick_params',
#  'ticklabel_format',
#  'tight_layout',
#  'time',
#  'title',
#  'tricontour',
#  'tricontourf',
#  'tripcolor',
#  'triplot',
#  'twinx',
#  'twiny',
#  'unicode_literals',
#  'uninstall_repl_displayhook',
#  'violinplot',
#  'viridis',
#  'vlines',
#  'waitforbuttonpress',
#  'warn_deprecated',
#  'warnings',
#  'winter',
#  'xcorr',
#  'xkcd',
#  'xlabel',
#  'xlim',
#  'xscale',
#  'xticks',
#  'ylabel',
#  'ylim',
#  'yscale',
#  'yticks']
